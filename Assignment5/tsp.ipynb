# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import time
import tsp2
import tsp
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def plot_tour(tour): 
    "Plot the cities as circles and the tour as lines between them."
    plot_lines(list(tour) + [tour[0]])
    
def plot_lines(points, style='bo-'):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111)
    x = map(X, points)
    y = map(Y, points)
    ax.plot(x, y, style)
    for i in range(len(points)):
        ax.text(x[i], y[i], str(i+1))
        "Plot lines to connect a series of points."
    plt.axis('scaled'); plt.axis('on')

def plot_tsp(algorithm, cities):
    "Apply a TSP algorithm to cities, plot the resulting tour, and print information."
    # Find the solution and time how long it takes
    t0 = time.clock()
    tour = algorithm(cities)
    t1 = time.clock()
    assert valid_tour(tour, cities)
    plot_tour(tour); plt.show()
    print("{} city tour with length {:.1f} in {:.3f} secs for {}"
          .format(len(tour), tsp2.tour_length(tour), t1 - t0, algorithm.__name__))
    
def valid_tour(tour, cities):
    "Is tour a valid tour for these cities?"
    return set(tour) == set(cities) and len(tour) == len(cities)

# %%
fname = "tsp.txt"
cities = tsp2.read_cities(fname)

# %% [markdown]
# ## Best tour with altered nn_tsp

# %%
plot_tsp(tsp2.altered_nn_tsp, cities)
# Out:
# 25 city tour with length 26883.8 in 0.010 secs for altered_nn_tsp

# %% [markdown]
# ## Best tour with repated altered nn_tsp

# %%
plot_tsp(tsp2.repeated_altered_nn_tsp, cities)
# Out:
# 25 city tour with length 26442.7 in 0.102 secs for repeated_altered_nn_tsp

# %% [markdown]
# And 26442 is the correct solution.
